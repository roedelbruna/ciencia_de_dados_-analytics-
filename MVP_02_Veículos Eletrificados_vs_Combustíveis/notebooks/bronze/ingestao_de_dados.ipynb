# %% [markdown]
# # Veículos Eletrificados vs Combustíveis
#
# Este notebook carrega os dados brutos do projeto de comparação entre veículos eletrificados e combustíveis, diretamente das fontes originais (associações e órgãos reguladores), sem transformações significativas. Ao final, realiza uma validação inicial de carga por meio da conferência das dimensões dos DataFrames.
#
# **Fontes de dados:**
# - **ABVE** (Associação Brasileira de Veículos Elétricos): vendas de veículos eletrificados (2020–2024)
# - **ANP** (Agência Nacional do Petróleo): produção de etanol hidratado e gasolina C (2020–2024)

# %% [markdown]
# ## 1. Importação de bibliotecas
#
# Importação da biblioteca `pandas` para manipulação dos dados tabulares.

# %% [markdown]
# ## 2. Dados ABVE — Veículos Eletrificados
#
# Carregamento dos dados de vendas de veículos eletrificados da ABVE, no formato CSV com separador `;`, cobrindo o período de 2020 a 2024.

# %% [markdown]
# ## 3. Dados ANP — Etanol e Gasolina
#
# Carregamento dos dados da ANP referentes à produção de **etanol hidratado** e **gasolina C**, no formato CSV com separador `;`, cobrindo o período de 2020 a 2024. Ao final, realiza uma validação inicial de carga de dados por meio da conferência das dimensões dos DataFrames.

# %%
import pandas as pd

# %%
df_abve = pd.read_csv('../../data/abve_eletrificados_2020_2024.csv',
                      sep=';')
df_abve.head()

# %%
df_etanol = pd.read_csv('../../data/anp_etanol_hidratado_2020_2024.csv',
                          sep=';')

df_gasolina = pd.read_csv('../../data/anp_gasolina_c_2020_2024.csv', 
                          sep=';')

print('nEtanol:')
print(df_etanol.shape)

print('Gasolina:')
print(df_gasolina.shape)
