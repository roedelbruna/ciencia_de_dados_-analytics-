# %% [markdown]
# # Veículos Eletrificados vs Combustíveis
#
# Esta etapa tem como objetivo realizar a ingestão de dados brutos utilizados no MPV, preservando as informações disponibilizadas pelas fontes originais.
#
# **Fontes de dados:**
# - **ABVE** (Associação Brasileira de Veículos Elétricos): vendas de veículos eletrificados (2020–2024)
# - **ANP** (Agência Nacional do Petróleo): vendas de etanol hidratado e gasolina C (2020–2024)

# %% [markdown]
# ## Estrutura dos Dados Ingeridos
#
# Antes das etapas de transformação, foram verificadas as estruturas dos arquivos recebidos, incluindo a quantidade de colunas, tipos de dados e atributos disponíveis em cada fonte.

# %%
import pandas as pd

# %%
df_abve = pd.read_csv('../../data/abve_eletrificados_2020_2024.csv',
                      sep=';')
df_abve.head()

# %%
df_etanol = pd.read_csv('../../data/anp_etanol_hidratado_2020_2024.csv',
                          sep=';')

df_gasolina = pd.read_csv('../../data/anp_gasolina_c_2020_2024.csv', 
                          sep=';')

print('nEtanol:')
print(df_etanol.shape)

print('Gasolina:')
print(df_gasolina.shape)

# %% [markdown]
# ## Conclusão Camada Bronze
#
# Os dados foram carregados com sucesso para o ambiente Databricks e permanecem no seu formato original, preservando a rastreabilidade das fontes utilizadas no estudo.
